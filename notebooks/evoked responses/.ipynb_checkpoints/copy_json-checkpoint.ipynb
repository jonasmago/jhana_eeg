# %%
# %matplotlib qt

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import pandas as pd

import sys
sys.path.append('../..')
from utils.csv_utils import *
from utils.lsl_utils import *
from utils.MNE_utils import *

# %%
df = pd.read_excel(r'../jhana_metadata.xlsx', sheet_name=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-75d9aca64241> in <module>
# ----> 1 df = pd.read_excel(r'../jhana_metadata.xlsx', sheet_name=None)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
subject = 0
print (df['jhana_day1'].iloc[subject])
date = df['jhana_day1'].iloc[subject]['date']
eeg_device_n = df['jhana_day1'].iloc[subject]['eeg_device_n']
time = df['jhana_day1'].iloc[subject]['jhana_mmn_eeg_fname']

# %%
path = '../data/data_sd/'+eeg_device_n+'/'+date+'/'+time+'/EEG.csv'

# %%
ifile  = open(path, "r")
read = csv.reader(ifile)
for row in read :
    header = row
    break
array = np.genfromtxt(path, delimiter=',')[1:,:] #the last thing removes the first row which is the header

# %%
array
# Out:
# array([[ 6.32700000e+04, -2.00000000e+00,  0.00000000e+00, ...,
#         -3.71039557e+04, -1.35300652e+04, -4.42798670e+04],
#        [ 6.32700000e+04, -2.00000000e+00,  0.00000000e+00, ...,
#         -3.71623485e+04, -1.35827148e+04, -4.43907513e+04],
#        [ 6.32700000e+04, -2.00000000e+00,  0.00000000e+00, ...,
#         -3.73262717e+04, -1.37241764e+04, -4.46054381e+04],
#        ...,
#        [ 2.52210000e+04,  5.00000000e+00,  0.00000000e+00, ...,
#         -3.49226405e+04, -1.20335723e+04, -4.46116436e+04],
#        [ 2.52210000e+04,  5.00000000e+00,  0.00000000e+00, ...,
#         -3.47862528e+04, -1.19208264e+04, -4.44161574e+04],
#        [ 2.52210000e+04,  5.00000000e+00,  0.00000000e+00, ...,
#         -3.46981100e+04, -1.18461898e+04, -4.43125130e+04]])

# %%
info = mne.create_info(ch_names_bitbrain, ch_types=ch_types, sfreq=256)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c79a74d7096f> in <module>
# ----> 1 info = mne.create_info(ch_names_bitbrain, ch_types=ch_types, sfreq=256)
#
# NameError: name 'ch_types' is not defined

# %%
path_impedance = '/Volumes/Expansion/jhana_study/data/data_sd/eeg33/22-09-02/14-42-58/EEG-impedances.csv'
start = 0
header, sd_array = import_csv(path_impedance, verbose=False)
for i in range(len(header)):
    if i > 3:
        plt.plot(sd_array[start:,i], label=i)
plt.title('Impedance')
plt.legend()
plt.show()


Plot, Axis = plt.subplots()
plt.subplots_adjust(bottom=0.25)
for i in range(len(header)):
    if i > 3:
        l = plt.plot(sd_array[start:,i], label=i)
slider_color = 'White'
axis_position = plt.axes([0.2, 0.1, 0.65, 0.03],facecolor = slider_color)
slider_position = Slider(axis_position,'Pos', 0, len(sd_array[start:,i]))

def update(val):
    pos = slider_position.val
    Axis.axis([pos, pos+10000, 0, 5])
    Plot.canvas.draw_idle()
slider_position.on_changed(update)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
