# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib qt

import numpy as np
import autoreject
import csv
import matplotlib.pyplot as plt
import pandas as pd
import mne
import os
import sys
#sys.path.append('../..')
from atpbar import atpbar
#from utils.csv_utils_new import *
#from utils.lsl_utils_new import *
#from utils.MNE_utils import *

# %% [markdown]
# # testing cleaning strategies

# %%
def get_evokeds (epochs):
    evokeds = dict()
    subset = epochs['1']
    evokeds['standard'] = list(subset.iter_evoked())
    subset = epochs['-1']
    evokeds['oddball'] = list(subset.iter_evoked())
    return (evokeds)
def plot_evokeds(evokeds, condition):
    mne.viz.plot_compare_evokeds(evokeds, picks='Fz', ci=0.95, title=f'global oddball evoked response: {condition}') #Fz for MMN, Pz for LTP

# %% [markdown]
# ## Plot evoked plots

# %%
for condition in ['jhana_mmn', 'mindfulness_mmn', 'control_mmn']:
    fname = f'../../data/mne_raw_epochs_ar_all/{condition}.fif'

    epochs = mne.read_epochs(fname)    
    epochs.drop_bad(reject={'eeg': 100e-6})
    #epochs.filter(None,30)
    #epochs.crop(tmax=0.5)

    evokeds = get_evokeds(epochs)
    plot_evokeds (evokeds, condition)
    
    plt.savefig(fname[:-4]+".png")
# Out:
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar_all/jhana_mmn.fif ...
# /var/folders/bq/hl737msd54q59fzf7spf0r7h0000gn/T/ipykernel_94464/2959759215.py:4: RuntimeWarning: This filename (../../data/mne_raw_epochs_ar_all/jhana_mmn.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(fname)
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 12810 matching events found
# No baseline correction applied
# 0 projection items activated
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['P8', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7']
#     Rejecting  epoch based on EEG : ['P8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'CP2', 'P7', 'Pz', 'O1']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['CP2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['CP2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['CP2', 'P7']
#     Rejecting  epoch based on EEG : ['CP1', 'P7', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P8', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['T7', 'P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['P7', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['CP2', 'P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['CP2', 'P7', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['Fp2', 'F8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['CP2']
#     Rejecting  epoch based on EEG : ['F8', 'FC5', 'FC6', 'T7', 'C3', 'T8', 'CP5', 'CP6', 'P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['CP2', 'P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O2']
#     Rejecting  epoch based on EEG : ['CP2', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7', 'O1']
#     Rejecting  epoch based on EEG : ['T7', 'CP2', 'P7']
#     Rejecting  epoch based on EEG : ['CP1']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7', 'O2']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['POz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['CP2']
#     Rejecting  epoch based on EEG : ['CP2', 'P7']
#     Rejecting  epoch based on EEG : ['T7', 'P7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['CP2', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'POz']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'P7', 'O1']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P8', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O1']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7', 'P7', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7', 'P7', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7']
#     Rejecting  epoch based on EEG : ['CP1', 'P7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7', 'P7', 'P8', 'O2']
#     Rejecting  epoch based on EEG : ['P8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['CP2', 'P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['FC5', 'T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FC5', 'T7', 'O1']
#     Rejecting  epoch based on EEG : ['F8', 'T7', 'T8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['Fp2', 'FC6']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'F7']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Fp2', 'F8']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['Fp1', 'F7', 'C3', 'T8', 'CP5', 'O2']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['FC5', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fp1', 'F7', 'F3', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'F3', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['Fp1', 'F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Fp1', 'F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fp1']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'P7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F7', 'F8', 'FC5']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7', 'F8', 'T7']
#     Rejecting  epoch based on EEG : ['Fp2', 'F8']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F7', 'T8']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7', 'P7']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['AF3', 'F7', 'F3', 'F8', 'FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F7', 'F8', 'P7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'F8', 'FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'POz']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['F7', 'FC5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7', 'T8', 'CP5', 'P8']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'P7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T8', 'CP6', 'P8', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7', 'O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7', 'O1']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F7', 'F3', 'F8', 'FC5', 'FC6', 'T7', 'C3', 'T8', 'CP6', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7', 'O1']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC2', 'T8', 'Pz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['T7', 'P8', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['AF4', 'Fz', 'P7', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Fz', 'T7', 'P7', 'Oz']
#     Rejecting  epoch based on EEG : ['F7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['AF3', 'F8', 'O1']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F8', 'T7']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Fp2', 'AF3', 'AF4', 'F7', 'F3', 'F4', 'F8', 'FC5', 'FC6', 'T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['T7', 'Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'P7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'P7', 'Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['F4', 'P7']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF4', 'F7', 'FC2', 'P3', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7', 'P7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['P4', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['FC5', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['FC1', 'P7', 'POz']
#     Rejecting  epoch based on EEG : ['FC1', 'P7']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['FC1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['FC1', 'Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['FC1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['FC1', 'POz']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['FC1', 'POz', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['P7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['FC1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['FC1', 'POz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['FC1', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'P7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'F7', 'FC5', 'FC1', 'FC6', 'T7', 'C3', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'F7', 'Fz', 'F8', 'FC5', 'FC1', 'FC6', 'T7', 'C3', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'F7', 'Fz', 'F8', 'FC5', 'FC1', 'FC6', 'T7', 'C3', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'F7', 'Fz', 'F8', 'FC5', 'FC1', 'FC6', 'T7', 'C3', 'P7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'F7', 'Fz', 'F8', 'FC5', 'FC1', 'FC6', 'T7', 'C3', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'F7', 'Fz', 'F8', 'FC5', 'FC1', 'FC6', 'T7', 'C3', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'P7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'POz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['P7', 'POz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['F3']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'P7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['P8', 'POz']
#     Rejecting  epoch based on EEG : ['Oz']
#     Rejecting  epoch based on EEG : ['AF4', 'Oz']
#     Rejecting  epoch based on EEG : ['F3']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8', 'O2']
#     Rejecting  epoch based on EEG : ['F3', 'P8']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['F3']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Fp1', 'F8']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'F7', 'F3', 'Fz', 'F8', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'T8', 'CP1', 'CP2', 'P3', 'Pz', 'P4', 'POz', 'Oz']
#     Rejecting  epoch based on EEG : ['Fpz', 'Fp2', 'AF3', 'F7']
#     Rejecting  epoch based on EEG : ['Fp2', 'F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['Fp2', 'F8']
#     Rejecting  epoch based on EEG : ['Fp2', 'F8', 'P8']
#     Rejecting  epoch based on EEG : ['Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F8', 'T7', 'T8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fp2', 'F7', 'F3', 'F4', 'F8', 'FC5', 'FC1', 'FC6', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'P7', 'P3', 'Pz', 'P8', 'POz', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['FC6', 'C4', 'CP5', 'CP1', 'P7', 'P3', 'P8', 'POz', 'O2']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
# ...
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF3', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fp2', 'F7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P7', 'P8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['F7', 'P7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fp2', 'T7', 'P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['T8', 'O1']
#     Rejecting  epoch based on EEG : ['T7', 'T8', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['AF3']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fpz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['AF3', 'T7']
#     Rejecting  epoch based on EEG : ['AF3', 'O1']
#     Rejecting  epoch based on EEG : ['T7', 'P8']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'P8', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['F7', 'T8', 'CP5', 'O1']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T8', 'P7', 'O1']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['AF3', 'T7', 'O2']
#     Rejecting  epoch based on EEG : ['AF3', 'O2']
#     Rejecting  epoch based on EEG : ['T7', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fp2', 'AF3', 'F7']
#     Rejecting  epoch based on EEG : ['Fp1', 'T7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fp2', 'FC5', 'T7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['AF3']
#     Rejecting  epoch based on EEG : ['AF3']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['AF3', 'P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O2']
#     Rejecting  epoch based on EEG : ['AF3']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fp2', 'AF3']
#     Rejecting  epoch based on EEG : ['C3', 'T8']
#     Rejecting  epoch based on EEG : ['AF3']
#     Rejecting  epoch based on EEG : ['Fp2', 'AF4', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['AF3']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['C3']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Fp1', 'T7', 'CP5']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['F7', 'T7']
#     Rejecting  epoch based on EEG : ['T7', 'C3']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7', 'CP5']
#     Rejecting  epoch based on EEG : ['T7', 'C3']
#     Rejecting  epoch based on EEG : ['T7', 'C3']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['C3']
#     Rejecting  epoch based on EEG : ['T7', 'CP5']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['C3']
#     Rejecting  epoch based on EEG : ['T7', 'C3']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fp2', 'T7']
#     Rejecting  epoch based on EEG : ['T7', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'P7']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['CP5', 'P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['T7', 'P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['AF4', 'T7', 'P7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['CP5', 'P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7', 'CP5']
#     Rejecting  epoch based on EEG : ['FC5', 'T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['AF4', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['Fp2']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['FC5', 'T7']
#     Rejecting  epoch based on EEG : ['FC5', 'T7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['FC5', 'T7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['Fp2', 'AF4', 'F8']
#     Rejecting  epoch based on EEG : ['Fp2', 'F8', 'FC6', 'T7', 'T8', 'P7']
#     Rejecting  epoch based on EEG : ['Fp2', 'F8', 'T7', 'P7', 'O1']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['Fp1', 'Fpz', 'Fp2', 'AF4', 'F8', 'FC5', 'FC6', 'T8', 'Oz']
#     Rejecting  epoch based on EEG : ['F8', 'T8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P3']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
# 2141 bad epochs dropped

# %%
condition = "mindfulness_mmn"    
fname = f'../../data/mne_raw_epochs_ar_all/{condition}.fif'
epochs = mne.read_epochs(fname)  
len(epochs)
# Out:
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar_all/mindfulness_mmn.fif ...
# /var/folders/bq/hl737msd54q59fzf7spf0r7h0000gn/T/ipykernel_94464/3245024184.py:3: RuntimeWarning: This filename (../../data/mne_raw_epochs_ar_all/mindfulness_mmn.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(fname)
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 11504 matching events found
# No baseline correction applied
# 0 projection items activated
# 11504

# %% [markdown]
# # compare evokeds evokeds INDIVIDUAL (Jhana & Mindfulness)

# %%
meditation
# Out:
# 'mindfulness'

# %%
subjects = ['sub0', 'sub1', 'sub2', 'sub3', 'sub4', 'sub5', 'sub6', 'sub7', 'sub8', 'sub9']
days = ['day1', 'day2', 'day3', 'day4']
meditations = ['jhana', 'mindfulness']

# Initialize an empty list to store each DataFrame
df = []
dfs = []

for subject in subjects:
    for day in days:
        for meditation in meditations: 
            path = f'../../data/mne_raw_epochs_ar/{meditation}_mmn/{subject}-{day}-{meditation}_mmn-raw_phot-events_epo.fif'
            
            try: 
                epochs = mne.read_epochs(path)
                evokeds = get_evokeds(epochs)
                mean_by_condition = []
                for cond_name in ['oddball', 'standard']:
                    mean_100_250 = []
                    mean_250_500 = []
                    for i in range(len(evokeds[cond_name])):
                        start = np.where(evokeds[cond_name][i].times >= 0.1)[0][0]  # Find the index where time is 0s
                        end = np.where(evokeds[cond_name][i].times <= 0.25)[0][-1]  # Find the index where time is 1s
                        tmp = np.mean(evokeds[cond_name][i].pick(['Fz']).data[0,start:end])
                        mean_100_250.append(tmp)

                        start = np.where(evokeds[cond_name][i].times >= 0.25)[0][0]  # Find the index where time is 0s
                        end = np.where(evokeds[cond_name][i].times <= 0.5)[0][-1]  # Find the index where time is 1s
                        tmp = np.mean(evokeds[cond_name][i].pick(['Fz']).data[0,start:end])
                        mean_250_500.append(tmp)

                    mean_100_250 = np.mean(mean_100_250)
                    mean_250_500 = np.mean(mean_250_500)
                    df = pd.DataFrame([[mean_100_250]], columns=['mean_100_250'])
                    df['mean_250_500'] = mean_250_500
                    df['subject'] = subject
                    df['day'] = day
                    df['condition'] = cond_name
                    df['meditation'] = meditation
                    dfs.append(df)

            except: 
                print ("========================")
                print ('this file did not work:')
                print (path)
                print ("$$$$$$$$$$$$$$$$$$$$$$$$")
                

# Combine all DataFrames
df = pd.concat(dfs, ignore_index=True)

print('\n' * 2)
mean_comparison = df.groupby(['meditation', 'condition'])['mean_100_250'].mean()
print(mean_comparison)
print('\n' * 2)
mean_comparison = df.groupby(['meditation', 'condition'])['mean_250_500'].mean()
print(mean_comparison)
# Out:
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub0-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub0-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub0-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub0-day2-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 323 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub0-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub0-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 352 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub0-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 365 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub0-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub1-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub1-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 340 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub1-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 344 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub1-day2-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 235 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub1-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 368 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub1-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 259 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub1-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 242 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub1-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 301 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub2-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 368 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub2-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 368 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub2-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 364 matching events found
# No baseline correction applied
# 0 projection items activated
# ========================
# this file did not work:
# ../../data/mne_raw_epochs_ar/mindfulness_mmn/sub2-day2-mindfulness_mmn-raw_phot-events_epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub2-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub2-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 303 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub2-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 188 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub2-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 243 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub3-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 250 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub3-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 181 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub3-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 301 matching events found
# No baseline correction applied
# 0 projection items activated
# ========================
# this file did not work:
# ../../data/mne_raw_epochs_ar/mindfulness_mmn/sub3-day2-mindfulness_mmn-raw_phot-events_epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub3-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 362 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub3-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 206 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub3-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 270 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub3-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 309 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub4-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 201 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub4-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 265 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub4-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 290 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub4-day2-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 285 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub4-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 315 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub4-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 339 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub4-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 241 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub4-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub5-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 367 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub5-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub5-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub5-day2-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub5-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub5-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 368 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub5-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 367 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub5-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 299 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub6-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub6-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 295 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub6-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 354 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub6-day2-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub6-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 324 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub6-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 184 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub6-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 286 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub6-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub7-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 365 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub7-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 359 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub7-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 363 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub7-day2-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 370 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub7-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 368 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub7-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 358 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub7-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 362 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub7-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 45 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub8-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 324 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub8-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 354 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub8-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub8-day2-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 270 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub8-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 287 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub8-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 255 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub8-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 188 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub8-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 303 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub9-day1-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub9-day1-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub9-day2-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 318 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub9-day2-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 311 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub9-day3-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 369 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub9-day3-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 367 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/jhana_mmn/sub9-day4-jhana_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 356 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/evoked responses/../../data/mne_raw_epochs_ar/mindfulness_mmn/sub9-day4-mindfulness_mmn-raw_phot-events_epo.fif ...
#     Found the data of interest:
#         t =     -50.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 297 matching events found
# No baseline correction applied
# 0 projection items activated
#
#
#
# meditation   condition
# jhana        oddball     -6.540028e-07
#              standard    -4.724152e-08
# mindfulness  oddball     -1.192099e-06
#              standard    -1.245031e-07
# Name: mean_100_250, dtype: float64
#
#
#
# meditation   condition
# jhana        oddball      5.627664e-07
#              standard     7.091713e-07
# mindfulness  oddball     -6.431943e-08
#              standard     6.764313e-07
# Name: mean_250_500, dtype: float64

# %% [markdown]
# ## stats tetst

# %%
from scipy.stats import ttest_rel

def clean_series_pairs(series1, series2):
    """Return cleaned series by removing pairs with NaN values in either series."""
    mask = ~np.isnan(series1) & ~np.isnan(series2)
    return series1[mask], series2[mask]

def paired_ttest_all_sessions (df_input, meditation1, meditation2, condition1, condition2, feature, avg_subject=False):
    if avg_subject: 
        df = df_input.groupby(['subject', 'meditation', 'condition'])[feature].mean().reset_index()
    else:
        df=df_input
    series1 = df[(df['meditation'] == meditation1) & (df['condition'] == condition1)][feature]
    series2 = df[(df['meditation'] == meditation2) & (df['condition'] == condition2)][feature]
    series1_cleaned, series2_cleaned = clean_series_pairs(np.array(series1), np.array(series2))
    t_stat, p_val = ttest_rel(series1_cleaned, series2_cleaned)
    print (f'results for {feature}: {meditation1}–{condition1} VS. {meditation2}–{condition2}')
    print(f"paired t-test result: t = {t_stat}, p = {p_val}")

# %%
paired_ttest_all_sessions(df, 'jhana', 'jhana', 'oddball', 'standard', 'mean_100_250')
paired_ttest_all_sessions(df, 'mindfulness', 'mindfulness', 'oddball', 'standard', 'mean_100_250')
paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'oddball', 'oddball', 'mean_100_250')
paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'standard', 'standard', 'mean_100_250')

paired_ttest_all_sessions(df, 'jhana', 'jhana', 'oddball', 'standard', 'mean_250_500')
paired_ttest_all_sessions(df, 'mindfulness', 'mindfulness', 'oddball', 'standard', 'mean_250_500')
paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'oddball', 'oddball', 'mean_250_500')
paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'standard', 'standard', 'mean_250_500')
# Out:
# results for mean_100_250: jhana–oddball VS. jhana–standard
# paired t-test result: t = -2.8888053071315327, p = 0.006282316645958215
# results for mean_100_250: mindfulness–oddball VS. mindfulness–standard
# paired t-test result: t = -2.0976557471306694, p = 0.04282493093733922
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [47], in <cell line: 3>()
#       1 paired_ttest_all_sessions(df, 'jhana', 'jhana', 'oddball', 'standard', 'mean_100_250')
#       2 paired_ttest_all_sessions(df, 'mindfulness', 'mindfulness', 'oddball', 'standard', 'mean_100_250')
# ----> 3 paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'oddball', 'oddball', 'mean_100_250')
#       4 paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'standard', 'standard', 'mean_100_250')
#       6 paired_ttest_all_sessions(df, 'jhana', 'jhana', 'oddball', 'standard', 'mean_250_500')
#
# Input In [41], in paired_ttest_all_sessions(df_input, meditation1, meditation2, condition1, condition2, feature, avg_subject)
#      13 series1 = df[(df['meditation'] == meditation1) & (df['condition'] == condition1)][feature]
#      14 series2 = df[(df['meditation'] == meditation2) & (df['condition'] == condition2)][feature]
# ---> 15 series1_cleaned, series2_cleaned = clean_series_pairs(np.array(series1), np.array(series2))
#      16 t_stat, p_val = ttest_rel(series1_cleaned, series2_cleaned)
#      17 print (f'results for {feature}: {meditation1}–{condition1} VS. {meditation2}–{condition2}')
#
# Input In [41], in clean_series_pairs(series1, series2)
#       3 def clean_series_pairs(series1, series2):
#       4     """Return cleaned series by removing pairs with NaN values in either series."""
# ----> 5     mask = ~np.isnan(series1) & ~np.isnan(series2)
#       6     return series1[mask], series2[mask]
#
# ValueError: operands could not be broadcast together with shapes (40,) (38,)

# %% [markdown]
# ## testing features for Fpz

# %%
export_path = '/Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/'
subjects = ['sub0', 'sub1', 'sub2', 'sub3', 'sub4', 'sub5', 'sub6', 'sub7', 'sub8', 'sub9']
days = ['day1', 'day2', 'day3', 'day4']
meditations = ['jhana', 'mindfulness']

# Initialize an empty list to store each DataFrame
df = []
dfs = []

for subject in subjects:
    for day in days:
        for meditation in meditations:            
            file_path = f'{export_path}{subject}-{meditation}_mmn-{day}-epo.fif'
            try: 
                epochs = mne.read_epochs(file_path)                
                evokeds = dict()
                subset = epochs['1']
                evokeds['standard'] = list(subset.iter_evoked())
                subset = epochs['-1']
                evokeds['oddball'] = list(subset.iter_evoked())

                mean_by_condition = []
                for cond_name in ['oddball', 'standard']:
                    mean_50_70 = []
                    mean_40_50 = []
                    for i in range(len(evokeds[cond_name])):
                        start = np.where(evokeds[cond_name][i].times >= 0.5)[0][0]  # Find the index where time is 0s
                        end = np.where(evokeds[cond_name][i].times <= 0.7)[0][-1]  # Find the index where time is 1s
                        tmp = np.mean(evokeds[cond_name][i].pick_channels(['Fpz']).data[0,start:end])
                        mean_50_70.append(tmp)
                        
                        start = np.where(evokeds[cond_name][i].times >= 0.4)[0][0]  # Find the index where time is 0s
                        end = np.where(evokeds[cond_name][i].times <= 0.5)[0][-1]  # Find the index where time is 1s
                        tmp = np.mean(evokeds[cond_name][i].pick_channels(['Fpz']).data[0,start:end])
                        mean_40_50.append(tmp)
                        
                    mean_50_70 = np.mean(mean_50_70)
                    mean_40_50 = np.mean(mean_40_50)
                    df = pd.DataFrame([[mean_50_70]], columns=['mean_50_70'])
                    df['mean_40_50'] = mean_40_50
                    df['subject'] = subject
                    df['day'] = day
                    df['condition'] = cond_name
                    df['meditation'] = meditation
                    dfs.append(df)
            except: 
                print ("========================")
                print ('this file did not work:')
                print (file_path)
                print ("$$$$$$$$$$$$$$$$$$$$$$$$")


# Combine all DataFrames
df = pd.concat(dfs, ignore_index=True)

print('\n' * 2)
mean_comparison = df.groupby(['meditation', 'condition'])['mean_10_15'].mean()
print(mean_comparison)
print('\n' * 2)
mean_comparison = df.groupby(['meditation', 'condition'])['mean_15_20'].mean()
print(mean_comparison)
# Out:
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-jhana_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 65 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-jhana_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 233 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-mindfulness_mmn-day2-epo.fif ...
# ========================
# this file did not work:
# /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-mindfulness_mmn-day2-epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 34 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 43 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-jhana_mmn-day4-epo.fif ...
# ========================
# this file did not work:
# /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-jhana_mmn-day4-epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-mindfulness_mmn-day4-epo.fif ...
# ========================
# this file did not work:
# /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub0-mindfulness_mmn-day4-epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub1-jhana_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 181 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub1-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 259 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub1-jhana_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 168 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub1-mindfulness_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 34 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub1-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 284 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub1-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 225 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub1-jhana_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 296 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub1-mindfulness_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 229 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub2-jhana_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 294 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub2-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 315 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub2-jhana_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 369 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub2-mindfulness_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 365 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub2-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 136 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub2-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 334 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub2-jhana_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 2 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub2-mindfulness_mmn-day4-epo.fif ...
# ========================
# this file did not work:
# /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub2-mindfulness_mmn-day4-epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub3-jhana_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 142 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub3-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 67 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub3-jhana_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 336 matching events found
# No baseline correction applied
# 0 projection items activated
# /opt/anaconda3/envs/bitbrain/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/bitbrain/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub3-mindfulness_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 361 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub3-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 2 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub3-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 192 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub3-jhana_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 109 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub3-mindfulness_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 109 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub4-jhana_mmn-day1-epo.fif ...
# ========================
# this file did not work:
# /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub4-jhana_mmn-day1-epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub4-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 93 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub4-jhana_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 202 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub4-mindfulness_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 293 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub4-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 66 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub4-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 277 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub4-jhana_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 118 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub4-mindfulness_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 2 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub5-jhana_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 124 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub5-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 190 matching events found
# No baseline correction applied
# 0 projection items activated
# /opt/anaconda3/envs/bitbrain/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/bitbrain/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub5-jhana_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 344 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub5-mindfulness_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 360 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub5-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 161 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub5-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 200 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub5-jhana_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 58 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub5-mindfulness_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 332 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-jhana_mmn-day1-epo.fif ...
# ========================
# this file did not work:
# /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-jhana_mmn-day1-epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-jhana_mmn-day2-epo.fif ...
# ========================
# this file did not work:
# /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-jhana_mmn-day2-epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-mindfulness_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 231 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 170 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 165 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-jhana_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 289 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub6-mindfulness_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 296 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub7-jhana_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 254 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub7-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub7-jhana_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 266 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub7-mindfulness_mmn-day2-epo.fif ...
# ========================
# this file did not work:
# /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub7-mindfulness_mmn-day2-epo.fif
# $$$$$$$$$$$$$$$$$$$$$$$$
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub7-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 274 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub7-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub7-jhana_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 314 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub7-mindfulness_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub8-jhana_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 179 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub8-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub8-jhana_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 61 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub8-mindfulness_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 229 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub8-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub8-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 106 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub8-jhana_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 301 matching events found
# No baseline correction applied
# 0 projection items activated
# /opt/anaconda3/envs/bitbrain/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/bitbrain/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub8-mindfulness_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 266 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub9-jhana_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 78 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub9-mindfulness_mmn-day1-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 340 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub9-jhana_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 351 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub9-mindfulness_mmn-day2-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 281 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub9-jhana_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 256 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub9-mindfulness_mmn-day3-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 329 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub9-jhana_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 323 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/Jhana_US/analysis/epochs_mmn/sub9-mindfulness_mmn-day4-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 358 matching events found
# No baseline correction applied
# 0 projection items activated
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 57>()
#      54 df = pd.concat(dfs, ignore_index=True)
#      56 print('\n' * 2)
# ---> 57 mean_comparison = df.groupby(['meditation', 'condition'])['mean_10_15'].mean()
#      58 print(mean_comparison)
#      59 print('\n' * 2)
#
# File /opt/anaconda3/envs/bitbrain/lib/python3.9/site-packages/pandas/core/groupby/generic.py:1338, in DataFrameGroupBy.__getitem__(self, key)
#    1329 if isinstance(key, tuple) and len(key) > 1:
#    1330     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1331     # valid syntax, so don't raise warning
#    1332     warnings.warn(
#    1333         "Indexing with multiple keys (implicitly converted to a tuple "
#    1334         "of keys) will be deprecated, use a list instead.",
#    1335         FutureWarning,
#    1336         stacklevel=find_stack_level(),
#    1337     )
# -> 1338 return super().__getitem__(key)
#
# File /opt/anaconda3/envs/bitbrain/lib/python3.9/site-packages/pandas/core/base.py:250, in SelectionMixin.__getitem__(self, key)
#     248 else:
#     249     if key not in self.obj:
# --> 250         raise KeyError(f"Column not found: {key}")
#     251     subset = self.obj[key]
#     252     ndim = subset.ndim
#
# KeyError: 'Column not found: mean_10_15'

# %%
paired_ttest_all_sessions(df, 'jhana', 'jhana', 'oddball', 'standard', 'mean_50_70')
paired_ttest_all_sessions(df, 'mindfulness', 'mindfulness', 'oddball', 'standard', 'mean_50_70')
paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'oddball', 'oddball', 'mean_50_70')
paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'standard', 'standard', 'mean_50_70')

paired_ttest_all_sessions(df, 'jhana', 'jhana', 'oddball', 'standard', 'mean_40_50')
paired_ttest_all_sessions(df, 'mindfulness', 'mindfulness', 'oddball', 'standard', 'mean_40_50')
paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'oddball', 'oddball', 'mean_40_50')
paired_ttest_all_sessions(df, 'jhana', 'mindfulness', 'standard', 'standard', 'mean_40_50')
# Out:
# results for mean_50_70: jhana–oddball VS. jhana–standard
# paired t-test result: t = -1.823701869420401, p = 0.07726543575009233
# results for mean_50_70: mindfulness–oddball VS. mindfulness–standard
# paired t-test result: t = -2.928057418839717, p = 0.006047301614155763
# results for mean_50_70: jhana–oddball VS. mindfulness–oddball
# paired t-test result: t = 0.5520880566672495, p = 0.584723631262074
# results for mean_50_70: jhana–standard VS. mindfulness–standard
# paired t-test result: t = 1.4371110186439655, p = 0.15956671585254983
# results for mean_40_50: jhana–oddball VS. jhana–standard
# paired t-test result: t = -1.7213839384528926, p = 0.09454489114930884
# results for mean_40_50: mindfulness–oddball VS. mindfulness–standard
# paired t-test result: t = -2.6282890122027647, p = 0.012786830657581374
# results for mean_40_50: jhana–oddball VS. mindfulness–oddball
# paired t-test result: t = 0.14114149168666407, p = 0.8886429498957689
# results for mean_40_50: jhana–standard VS. mindfulness–standard
# paired t-test result: t = 1.1541395197025113, p = 0.25626307611757293
