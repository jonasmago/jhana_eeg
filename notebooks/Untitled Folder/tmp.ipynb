# %%
import glob
import mne

# %%
files = glob.glob('../../data/mne_raw/*jhana_mmn*-events.fif')

# %%
raw = mne.io.read_raw_fif(files[1])
# Out:
# Opening raw data file ../../data/mne_raw/sub1-day2-jhana_mmn-raw_phot-events.fif...
#     Range : 256 ... 216831 =      1.000 ...   846.996 secs
# Ready.
# /var/folders/bq/hl737msd54q59fzf7spf0r7h0000gn/T/ipykernel_90533/320365240.py:1: RuntimeWarning: This filename (../../data/mne_raw/sub1-day2-jhana_mmn-raw_phot-events.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(files[1])

# %%
raw.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1088.64x659.52 with 4 Axes>
# <MNEBrowseFigure size 1088.64x659.52 with 4 Axes>
