# %%
import os
import glob
import mne
import numpy as np
import pandas as pd

INPUT_DIRS = [
    'control_counting',
    'control_resting_state',
    'nimitta',
    'rest_baseline',
    'resting_state',
    'resting_state_byjhana_concatenated'
]

OUTPUT_BASE = 'ALL_NoooAr'

os.makedirs(OUTPUT_BASE, exist_ok=True)

for folder in ['raw', '03s', '10s', 'raw_interpolated', '03s_ar', '10s_ar']:
    os.makedirs(os.path.join(OUTPUT_BASE, folder), exist_ok=True)

summary = []

def parse_metadata(path):
    fname = os.path.basename(path).lower()
    control = '1' if 'control' in path else '0'
    
    sub = fname.split('-')[0].replace('sub', '').zfill(2)
    day = 'NA'
    if 'day' in fname:
        try:
            day = fname.split('-')[1].replace('day', '')
            day = str(day).zfill(2)
        except IndexError:
            pass
    
    if 'counting' in path:
        condition = 'count'
    elif 'mindfulness' in path:
        condition = 'mindf'
    elif 'nimitta' in path:
        condition = 'nimit'
    elif 'rest_eyes_closed' in fname:
        condition = 'rposc' if 'post' in fname else 'rprec'
    elif 'rest_eyes_open' in fname:
        condition = 'rposo' if 'post' in fname else 'rpreo'
    elif 'jhana-j' in fname:
        jn = fname.split('-')[-1].replace('.fif', '')
        condition = f'jhan{jn[-1]}'
    elif 'jhana' in fname:
        condition = 'jhana'
    else:
        condition = 'unkn'
        
    return control, sub, day, condition

def build_filename(control, sub, day, condition, n_elem, length, bads, kind):
    day_str = day if day else ''
    return f"{control}_{sub}_{day_str}_{condition}_{n_elem}_{length}_{bads}_{kind}.fif"

def remove_bads(raw):
    
    bad_segments = []
    for annot in raw.annotations:
        if annot['description'].lower() == 'bad_':
            bad_segments.append((annot['onset']-raw.first_time, annot['onset'] + annot['duration']-raw.first_time))

    good_segments = []
    start_time = 0

    for bad_start, bad_end in bad_segments:
        if bad_start - start_time >= 10:
            good_segments.append((start_time, bad_start))
        start_time = bad_end 

    if start_time < raw.times[-1]:  
        good_segments.append((start_time, raw.times[-1]))

    good_raws = [raw.copy().crop(tmin, tmax) for tmin, tmax in good_segments]

    if len(good_raws) > 0:
        raw_nobad = mne.concatenate_raws(good_raws)
    else: 
        raw_nobad = None

    return raw_nobad, str(len(good_segments)).zfill(3), str(int(raw_nobad.times[-1])).zfill(4)

for folder in INPUT_DIRS:
    files = sorted(glob.glob(os.path.join(folder, "*.fif")))[:1]
    for file in files: 
        print(f"🔄 Processing {file}")
        control, sub, day, condition = parse_metadata(file)
        raw = mne.io.read_raw_fif(file, preload=True)
        num_bad_channels = str(len(raw.info['bads'])).zfill(2)
        print(raw.info['bads'])
        raw_nobad, n_elem, length = remove_bads(raw)    

        
        fname = build_filename(control, sub, day, condition, n_elem, length, num_bad_channels, 'raw')
        fpath = os.path.join(OUTPUT_BASE, 'raw', fname)
        raw_nobad.save(fpath, overwrite=True)
        
        epochs_3 = mne.make_fixed_length_epochs(raw, duration=3, preload=True)
        epochs_10 = mne.make_fixed_length_epochs(raw, duration=10, preload=True)
        
        n_epochs_3 = len(epochs_3)
        length_3 = n_epochs_3 * 3
        n_epochs_3 = str(n_epochs_3).zfill(3)
        length_3 = str(length_3).zfill(4)

        n_epochs_10 = len(epochs_10)
        length_10 = n_epochs_10 * 10
        n_epochs_10 = str(n_epochs_10).zfill(3)
        length_10 = str(length_10).zfill(4)

        fname_3 = build_filename(control, sub, day, condition, n_epochs_3, length_3, num_bad_channels, 'epo')
        fname_10 = build_filename(control, sub, day, condition, n_epochs_10, length_10, num_bad_channels, 'epo')
        
        fpath_3 = os.path.join(OUTPUT_BASE, '03s', fname_3)
        epochs_3.save(fpath_3, overwrite=True)
        
        fpath_10 = os.path.join(OUTPUT_BASE, '10s', fname_10)
        epochs_10.save(fpath_10, overwrite=True)

        # interpolate and run AR
        raw_nobad.interpolate_bads(reset_bads=True)
        fpath = os.path.join(OUTPUT_BASE, 'raw_interpolated', fname)
        raw_nobad.save(fpath, overwrite=True)

        ar = AutoReject()
        epochs_3_ar, reject_log_3 = ar.fit_transform(epochs_3, return_log=True)
        epochs_3_ar.interpolate_bads(reset_bads=True)
        fpath_3_ar = os.path.join(OUTPUT_BASE, '03s_ar', fname_3)
        epochs_3_ar.save(fpath_3_ar, overwrite=True)

        
        ar = AutoReject()
        epochs_10_ar, reject_log_10 = ar.fit_transform(epochs_10, return_log=True)
        epochs_10_ar.interpolate_bads(reset_bads=True)
        fpath_10_ar = os.path.join(OUTPUT_BASE, '10s_ar', fname_10)
        epochs_10_ar.save(fpath_10_ar, overwrite=True)
        
        n_dropped_3 = reject_log_3.bad_epochs.sum()
        n_interp_total_3 = np.nansum(reject_log_3.labels)
    
        n_dropped_10 = reject_log_10.bad_epochs.sum()
        n_interp_total_10 = np.nansum(reject_log_10.labels)

        fig = reject_log_3.plot(show=False)
        fig.savefig(os.path.join(OUTPUT_BASE, '03s_ar', fname_3.replace('.fif', '_rejlog.png')))
        fig = reject_log_10.plot(show=False)
        fig.savefig(os.path.join(OUTPUT_BASE, '10s_ar', fname_10.replace('.fif', '_rejlog.png')))
        
        summary.append({
            'original_name': file, 'filename': fname, 
            'control': control, 'sub': sub, 'day': day, 'condition': condition,
            'bad_channels': num_bad_channels,
            'num_03s_epochs': n_epochs_3, 'num_10s_epochs': n_epochs_10, 
            'length_raw': length, 'length_03s': length_3, 'length_10s': length_10,
            'num_03s_epochs_ar': str(len(epochs_3_ar)).zfill(3), 'num_10s_epochs_ar': str(len(epochs_10_ar)).zfill(3),
            'length_03s_ar': str(int(len(epochs_3_ar))*3).zfill(4), 'length_10s_ar': str(int(len(epochs_10_ar))*10).zfill(4),
            'n_dropped_3': n_dropped_3, 'n_dropped_10': n_dropped_10,
            'n_interp_total_3': n_interp_total_3, 'n_interp_total_10': n_interp_total_10,
            'percent_retained_03s': round(len(epochs_3_ar) / int(n_epochs_3) * 100, 2),
            'percent_retained_10s': round(len(epochs_10_ar) / int(n_epochs_10) * 100, 2),

        })



    # Save combined summary
    df = pd.DataFrame(summary)
    summary_path = os.path.join(OUTPUT_BASE, 'summary.csv')
    df.to_csv(summary_path, index=False)
    df.to_excel(os.path.join(OUTPUT_BASE, 'summary.xlsx'), index=False)
    print(f"📝 Summary saved to {summary_path}")
    
    print("✅ All files processed.")
# Out:
# 🔄 Processing control_counting/sub0-control-counting-raw.fif
# Opening raw data file control_counting/sub0-control-counting-raw.fif...
#     Range : 512 ... 30976 =      2.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30464  =      0.000 ...   119.000 secs...
# []
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/1_00_NA_count_003_0081_00_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/1_00_NA_count_003_0081_00_raw.fif
# [done]
# Not setting metadata
# 39 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 39 events and 768 original time points ...
# 13 bad epochs dropped
# Not setting metadata
# 11 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 11 events and 2560 original time points ...
# 5 bad epochs dropped
# 🔄 Processing control_counting/sub1-control-counting-raw.fif
# Opening raw data file control_counting/sub1-control-counting-raw.fif...
#     Range : 14592 ... 34816 =     57.000 ...   136.000 secs
# Ready.
# Reading 0 ... 20224  =      0.000 ...    79.000 secs...
# ['O2', 'Oz', 'O1', 'P4', 'POz', 'P8']
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/1_01_NA_count_003_0054_06_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/1_01_NA_count_003_0054_06_raw.fif
# [done]
# Not setting metadata
# 26 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 26 events and 768 original time points ...
# 9 bad epochs dropped
# Not setting metadata
# 7 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 7 events and 2560 original time points ...
# 5 bad epochs dropped
# 🔄 Processing control_resting_state/sub0-control-mindfulness-raw.fif
# Opening raw data file control_resting_state/sub0-control-mindfulness-raw.fif...
#     Range : 512 ... 385024 =      2.000 ...  1504.000 secs
# Ready.
# Reading 0 ... 384512  =      0.000 ...  1502.000 secs...
# ['F4', 'O1', 'Oz', 'O2', 'F8', 'FC6', 'T7']
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/1_00_NA_mindf_031_1097_07_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/1_00_NA_mindf_031_1097_07_raw.fif
# [done]
# Not setting metadata
# 500 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 500 events and 768 original time points ...
# 144 bad epochs dropped
# Not setting metadata
# 150 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 150 events and 2560 original time points ...
# 72 bad epochs dropped
# 🔄 Processing control_resting_state/sub1-control-mindfulness-raw.fif
# Opening raw data file control_resting_state/sub1-control-mindfulness-raw.fif...
#     Range : 512 ... 385792 =      2.000 ...  1507.000 secs
# Ready.
# Reading 0 ... 385280  =      0.000 ...  1505.000 secs...
# ['T7', 'O1', 'Oz', 'O2', 'FC5', 'CP6', 'P4', 'P7']
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/1_01_NA_mindf_042_1262_08_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/1_01_NA_mindf_042_1262_08_raw.fif
# [done]
# Not setting metadata
# 501 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 501 events and 768 original time points ...
# /var/folders/bq/hl737msd54q59fzf7spf0r7h0000gn/T/ipykernel_36484/3324853442.py:84: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw_nobad = mne.concatenate_raws(good_raws)
# 108 bad epochs dropped
# Not setting metadata
# 150 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 150 events and 2560 original time points ...
# 67 bad epochs dropped
# 🔄 Processing nimitta/sub0-LTP_post-nimitta-raw.fif
# Opening raw data file nimitta/sub0-LTP_post-nimitta-raw.fif...
#     Range : 768 ... 77824 =      3.000 ...   304.000 secs
# Ready.
# Reading 0 ... 77056  =      0.000 ...   301.000 secs...
# ['O2']
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_NA_nimit_007_0264_01_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_NA_nimit_007_0264_01_raw.fif
# [done]
# Not setting metadata
# 100 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 100 events and 768 original time points ...
# 17 bad epochs dropped
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 2560 original time points ...
# 12 bad epochs dropped
# 🔄 Processing nimitta/sub0-LTP_pre-nimitta-raw.fif
# Opening raw data file nimitta/sub0-LTP_pre-nimitta-raw.fif...
#     Range : 512 ... 79360 =      2.000 ...   310.000 secs
# Ready.
# Reading 0 ... 78848  =      0.000 ...   308.000 secs...
# ['CP6']
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_NA_nimit_004_0302_01_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_NA_nimit_004_0302_01_raw.fif
# [done]
# Not setting metadata
# 102 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 102 events and 768 original time points ...
# 5 bad epochs dropped
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 30 events and 2560 original time points ...
# 4 bad epochs dropped
# 🔄 Processing rest_baseline/sub0-LTP_post-rest_eyes_closed-raw.fif
# Opening raw data file rest_baseline/sub0-LTP_post-rest_eyes_closed-raw.fif...
#     Range : 768 ... 32000 =      3.000 ...   125.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# ['P7', 'O2', 'P8', 'P4', 'Pz', 'POz']
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_NA_rposc_003_0050_06_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_NA_rposc_003_0050_06_raw.fif
# [done]
# Not setting metadata
# 40 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 40 events and 768 original time points ...
# 24 bad epochs dropped
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 12 events and 2560 original time points ...
# 10 bad epochs dropped
# 🔄 Processing rest_baseline/sub0-LTP_post-rest_eyes_open-raw.fif
# Opening raw data file rest_baseline/sub0-LTP_post-rest_eyes_open-raw.fif...
#     Range : 768 ... 32512 =      3.000 ...   127.000 secs
# Ready.
# Reading 0 ... 31744  =      0.000 ...   124.000 secs...
# ['O2', 'P7', 'O1']
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_NA_rposo_006_0078_03_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_NA_rposo_006_0078_03_raw.fif
# [done]
# Not setting metadata
# 41 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 41 events and 768 original time points ...
# 17 bad epochs dropped
# Not setting metadata
# 12 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 12 events and 2560 original time points ...
# 10 bad epochs dropped
# 🔄 Processing resting_state/sub0-day1-jhana-raw.fif
# Opening raw data file resting_state/sub0-day1-jhana-raw.fif...
#     Range : 512 ... 388096 =      2.000 ...  1516.000 secs
# Ready.
# Reading 0 ... 387584  =      0.000 ...  1514.000 secs...
# /var/folders/bq/hl737msd54q59fzf7spf0r7h0000gn/T/ipykernel_36484/3324853442.py:84: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw_nobad = mne.concatenate_raws(good_raws)
# ['T8', 'O2']
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_01_jhana_026_1253_02_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_01_jhana_026_1253_02_raw.fif
# [done]
# Not setting metadata
# 504 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 504 events and 768 original time points ...
# 98 bad epochs dropped
# Not setting metadata
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 2560 original time points ...
# 51 bad epochs dropped
# 🔄 Processing resting_state/sub0-day1-mindfulness-raw.fif
# Opening raw data file resting_state/sub0-day1-mindfulness-raw.fif...
#     Range : 512 ... 384768 =      2.000 ...  1503.000 secs
# Ready.
# Reading 0 ... 384256  =      0.000 ...  1501.000 secs...
# []
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_01_mindf_017_1384_00_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_00_01_mindf_017_1384_00_raw.fif
# [done]
# Not setting metadata
# 500 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 500 events and 768 original time points ...
# 56 bad epochs dropped
# Not setting metadata
# 150 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 150 events and 2560 original time points ...
# 30 bad epochs dropped
# 🔄 Processing resting_state_byjhana_concatenated/sub1-day1-jhana-j1.fif
# Opening raw data file resting_state_byjhana_concatenated/sub1-day1-jhana-j1.fif...
#     Range : 16391 ... 86653 =     64.027 ...   338.488 secs
# Ready.
# Reading 0 ... 70262  =      0.000 ...   274.461 secs...
# ['T7', 'F7', 'P4', 'C4', 'CP2']
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_01_01_jhan1_004_0235_05_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_01_01_jhan1_004_0235_05_raw.fif
# [done]
# Not setting metadata
# 91 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 91 events and 768 original time points ...
# 15 bad epochs dropped
# Not setting metadata
# 27 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 27 events and 2560 original time points ...
# 6 bad epochs dropped
# 🔄 Processing resting_state_byjhana_concatenated/sub1-day1-jhana-j2.fif
# Opening raw data file resting_state_byjhana_concatenated/sub1-day1-jhana-j2.fif...
#     Range : 67984 ... 200890 =    265.562 ...   784.727 secs
# Ready.
# Reading 0 ... 132906  =      0.000 ...   519.164 secs...
# ['T7', 'F7', 'P4', 'C4', 'CP2']
# /var/folders/bq/hl737msd54q59fzf7spf0r7h0000gn/T/ipykernel_36484/3324853442.py:95: RuntimeWarning: This filename (resting_state_byjhana_concatenated/sub1-day1-jhana-j1.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file, preload=True)
# /var/folders/bq/hl737msd54q59fzf7spf0r7h0000gn/T/ipykernel_36484/3324853442.py:95: RuntimeWarning: This filename (resting_state_byjhana_concatenated/sub1-day1-jhana-j2.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file, preload=True)
# Writing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_01_01_jhan2_010_0395_05_raw.fif
# Closing /Users/jonasmago/PhD_code_data/github/eeg_jhana/notebooks/hand_cleaning/ALL_NoooAr/raw/0_01_01_jhan2_010_0395_05_raw.fif
# [done]
# Not setting metadata
# 173 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 173 events and 768 original time points ...
# 44 bad epochs dropped
# Not setting metadata
# 51 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 51 events and 2560 original time points ...
# 23 bad epochs dropped
# 📝 Summary saved to ALL_NoooAr/summary.csv
# ✅ All files processed.
