# %%
from src.raw_to_epochs import *
import mne
import numpy as np
import glob

# %%
f_paths = sorted(glob.glob("/Users/jonasmago/PhD_code_data/Jhana US/analysis/mne.raw_resting_state/*.fif"))
for f_path in f_paths:
    raw = mne.io.read_raw_fif(f_path, preload=True)
    duration=10
    epochs, epochs_ar, reject_log = make_clean_epochs(raw, l_freq=1, h_freq=None, duration=duration, preload=True)
    eventsv, eventsv_ar = raw_to_eventsv_ar(raw, reject_log, duration=duration)

    #saving stuff
    folder = "../data/epochs_clean/"
    fname_base = os.path.basename(f_path)[:-8]+"_"
    reject_log.save(folder + fname_base + "reject_log.npz")
    #reject_log = autoreject.read_reject_log(fname)
    #reject_log.bad_epochs
    epochs.save(folder+fname_base+"all-epo.fif")
    epochs_ar.save(folder+fname_base+"ar-epo.fif")
    np.save(folder+fname_base+"eventsv.npy", eventsv)
    np.save(folder+fname_base+"eventsv_ar.npy", eventsv_ar)
# Out:
# Opening raw data file /Users/jonasmago/PhD_code_data/Jhana US/analysis/mne.raw_resting_state/sub0-jhana_restingstate-jhana_day1-raw.fif...
#     Range : 0 ... 388359 =      0.000 ...  1517.027 secs
# Ready.
# Reading 0 ... 388359  =      0.000 ...  1517.027 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Not setting metadata
# 151 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 151 events and 2560 original time points ...
# 0 bad epochs dropped
# Running autoreject on ch_type=eeg
# ...

# %% [markdown]
# # loading data

# %%
# only works for one subject
files = glob.glob("../data/epochs_clean/*")

reject_log = autoreject.read_reject_log(files[3])
#print(reject_log.bad_epochs)
epochs_ar = mne.read_epochs(files[0])
epochs = mne.read_epochs(files[1])
eventsv_ar = np.load(files[2])
eventsv = np.load(files[4])
# Out:
# Reading /Users/jonasmago/PhD_code_data/github/jhana/notebooks/../data/epochs_clean/sub0-mindfulness_restingstate-jhana_day3_ar-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    2996.09 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/jonasmago/PhD_code_data/github/jhana/notebooks/../data/epochs_clean/sub0-mindfulness_restingstate-jhana_day3_all-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    2996.09 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 20 matching events found
# No baseline correction applied
# 0 projection items activated

# %% [markdown]
# # connectivity
# [link](https://mne.tools/dev/auto_tutorials/epochs/60_make_fixed_length_epochs.html)
